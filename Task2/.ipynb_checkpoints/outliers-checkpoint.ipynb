# %% [markdown]
# ## Introduction
# Outliers are the point most distant to the regression line. Their location can bedetected by plotting a visual representation and by performing certain calculations like standarddeviation. Outlier’s distance from the regression line is calculated as follows: $\left | y-\widehat{y} \right |> 2 \sqrt{\frac{SSE}{n-2}}$, where n is the number of data points, SSE is the sum of squared errors, y is the true value and y hat is the prediction.This facilitates its detection. For example, in a  2-dimensionalspace, a point P will be considered an outlier if it is not between D-2s and D+2s, where Dis the regression line and $\ s = \sqrt{\frac{SSE}{n-2}}$. We use this characteristic of an outlier as a basis to initiate the function with the input values quantity outliers and number of generated points.

# %% [markdown]
# ## Content:
# - [Part 1](#part1)-  Generating Data
# - [Part 2](#part2)- Simple Regression
# - [Part 3](#part3) -  Effect of adding one outlier
# - [Part 4](#part4) -  Detection of outliers
# - [Part 5](#part5) -  Impact of number of outliers on the Regression
# - [Part 6](#part6) -  Conclusion

# %%
import numpy as np
import math
import sklearn
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from abc import ABC, abstractmethod
from numpy.random import default_rng
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression

# %%
rng = default_rng(seed=0)

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part1'></a>
#
# # Part 1 -  Generating  Data

# %%
## Generate data points with a class
class Data2D:
    
    def __init__(self, slope = (1, 1), noise_variance = 1 ):
        
        # intialize member variables here 
        self.slope = slope
        self.noise_variance = noise_variance
        
        
        
    def generate_points(self, N = 50):
    
        slope = self.slope
        noise_variance = self.noise_variance

        # initialize noise epsilon 
        epsilon = rng.normal(0, noise_variance**(1/2), N)

        ## Generate N points

        # Adding the X_0 coordinates full of ones for vector multiplications
        X_0 = np.ones(N)
        # for X_1 generate random points between -15,15
        X_1 = 30*(np.random.random(N)-0.5)

        # We create a design matrix, where rows are datapoints and columns are features, or input dimensions
        X = np.vstack( [X_0, X_1]).transpose()

        # initialize **y** with the equation of line here. Equation of line is written in the desciption above, 
        # line parameters (a,b, c) are stored in a local variable

        y = X.dot(np.array(slope)) + epsilon

        return X, y

# %%
## Function to generate data with noise
def generate_data(slope = (1,1), noise_variance=1, N = 50):
    
    # initialize noise epsilon 
    epsilon = rng.normal(0, noise_variance**(1/2), N)
    
    ## Generate N points
    
    # Adding the X_0 coordinates full of ones for vector multiplications
    X_0 = np.ones(N)
    # for X_1 generate random points between -15,15
    X_1 = 30*(np.random.random(N)-0.5)
    
    # We create a design matrix, where rows are datapoints and columns are features, or input dimensions
    X = np.vstack( [X_0, X_1]).transpose()
    
    # initialize **y** with the equation of line here. Equation of line is written in the desciption above, 
    # line parameters (a,b, c) are stored in a local variable

    y = X.dot(np.array(slope)) + epsilon
    
    return X, y

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part2'></a>
#
# # Part 2 -  Simple Regression

# %%
# Function that returns regression params
def regression(X, y) :
    reg = LinearRegression().fit(X.reshape(-1,1), y)
    
    return reg.coef_[0], reg.intercept_, reg.score(X, y)

# %%
s = (-1,2)
X, y = generate_data(s, 4, 100)
ar, br, cr = regression(X[:,1].reshape(-1,1), y)
print('Regression slope : %.3f' % ar, 'Regression intercept : %.3f' % br, 'Regression score : %.3f' % cr)
plt.plot(X[:,1],ar*X[:,1]+br, c='red')
plt.scatter(X[:,1],y)
plt.title('Linear Regression fit on generated data')
plt.show();
# Out:
# Regression slope : 1.991 Regression intercept : -0.837 Regression score : 0.989

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part3'></a>
#
# # Part 3 -  Effect of adding one outlier

# %%
## Adding one outlier
outlier = (20,0)
Xo = np.append(X[:,1],outlier[0])
yo = np.append(y,outlier[1])

# %%
a, b, c = regression(Xo.reshape(-1,1), yo)
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)
plt.plot(Xo,a*Xo+b, c='red')
plt.scatter(Xo,yo)
plt.title('Linear Regression fit on generated data with added outlier')

plt.show();
# Out:
# Regression slope : 1.902 Regression intercept : -1.195 Regression score : 0.945

# %%
## Studying the impact of adding one outlier on randomly generated data with one outlier
## Each time we change the outlier and see what happens
slopes = []
intercepts = []
reg_score = []
distances = []
for i in range(100):
    outlier = (-50+i, -30)
    Xo = np.append(X[:,1],outlier[0])
    yo = np.append(y,outlier[1])
    slope, intercept, score = regression(Xo.reshape(-1,1), yo)
    slopes.append(slope)
    intercepts.append(intercept)
    reg_score.append(score)
    a = s[1]
    b = s[0]
    distance = np.absolute((a*outlier[0]+b-outlier[1])/(np.sqrt(a**2+1)))
    distance_reg = np.absolute((slope*outlier[0]+intercept-outlier[1])/(np.sqrt(slope**2+1)))
    distances.append(distance)
    if i%5 == 0 :
        print('Regression slope : %.3f' % ar,'Outlier Reg slope : %.3f' % slope)  
        print('Regression intercept : %.3f' % br,'Outlier Reg intercept : %.3f' % intercept)
        print('Regression score : %.3f' % cr,'Outlier Reg score : %.3f' % score)
        print('The outlier distance from the green line is : %.2f' % distance)
        print('The outlier distance from the red line is : %.2f' % distance_reg)
        z = np.ones(len(y)+1)
        z[len(y)] = 0
        plt.plot(Xo,slope*Xo+intercept, c='red', label = f'Regression line with outilier :  {outlier} ', alpha = 0.7)
        plt.plot(Xo,a*Xo+b, c='green', label = f'Original Line', alpha = 0.7)
        plt.scatter(Xo[:len(y)],yo[:len(y)], marker = 'o', cmap='Spectral', alpha = 0.6 )
        plt.scatter(Xo[len(y)],yo[len(y)], marker = 'x', cmap='summer')
        plt.legend(loc = 'upper left')
        plt.show();
# Out:
# Regression slope : 1.991 Outlier Reg slope : 1.663
# Regression intercept : -0.837 Outlier Reg intercept : -0.264
# Regression score : 0.989 Outlier Reg score : 0.877
# The outlier distance from the green line is : 31.75
# The outlier distance from the red line is : 27.53
# Regression slope : 1.991 Outlier Reg slope : 1.726
# Regression intercept : -0.837 Outlier Reg intercept : -0.325
# Regression score : 0.989 Outlier Reg score : 0.903
# The outlier distance from the green line is : 27.28
# The outlier distance from the red line is : 24.06
# Regression slope : 1.991 Outlier Reg slope : 1.786
# Regression intercept : -0.837 Outlier Reg intercept : -0.394
# Regression score : 0.989 Outlier Reg score : 0.926
# The outlier distance from the green line is : 22.81
# The outlier distance from the red line is : 20.44
# Regression slope : 1.991 Outlier Reg slope : 1.841
# Regression intercept : -0.837 Outlier Reg intercept : -0.470
# Regression score : 0.989 Outlier Reg score : 0.947
# The outlier distance from the green line is : 18.34
# The outlier distance from the red line is : 16.66
# Regression slope : 1.991 Outlier Reg slope : 1.891
# Regression intercept : -0.837 Outlier Reg intercept : -0.552
# Regression score : 0.989 Outlier Reg score : 0.964
# The outlier distance from the green line is : 13.86
# The outlier distance from the red line is : 12.75
# Regression slope : 1.991 Outlier Reg slope : 1.933
# Regression intercept : -0.837 Outlier Reg intercept : -0.640
# Regression score : 0.989 Outlier Reg score : 0.977
# The outlier distance from the green line is : 9.39
# The outlier distance from the red line is : 8.71
# Regression slope : 1.991 Outlier Reg slope : 1.966
# Regression intercept : -0.837 Outlier Reg intercept : -0.733
# Regression score : 0.989 Outlier Reg score : 0.986
# The outlier distance from the green line is : 4.92
# The outlier distance from the red line is : 4.56
# Regression slope : 1.991 Outlier Reg slope : 1.990
# Regression intercept : -0.837 Outlier Reg intercept : -0.830
# Regression score : 0.989 Outlier Reg score : 0.989
# The outlier distance from the green line is : 0.45
# The outlier distance from the red line is : 0.30
# Regression slope : 1.991 Outlier Reg slope : 2.002
# Regression intercept : -0.837 Outlier Reg intercept : -0.929
# Regression score : 0.989 Outlier Reg score : 0.987
# The outlier distance from the green line is : 4.02
# The outlier distance from the red line is : 4.04
# Regression slope : 1.991 Outlier Reg slope : 2.003
# Regression intercept : -0.837 Outlier Reg intercept : -1.028
# Regression score : 0.989 Outlier Reg score : 0.978
# The outlier distance from the green line is : 8.50
# The outlier distance from the red line is : 8.47
# Regression slope : 1.991 Outlier Reg slope : 1.992
# Regression intercept : -0.837 Outlier Reg intercept : -1.126
# Regression score : 0.989 Outlier Reg score : 0.964
# The outlier distance from the green line is : 12.97
# The outlier distance from the red line is : 12.96
# Regression slope : 1.991 Outlier Reg slope : 1.968
# Regression intercept : -0.837 Outlier Reg intercept : -1.220
# Regression score : 0.989 Outlier Reg score : 0.944
# The outlier distance from the green line is : 17.44
# The outlier distance from the red line is : 17.49
# Regression slope : 1.991 Outlier Reg slope : 1.933
# Regression intercept : -0.837 Outlier Reg intercept : -1.310
# Regression score : 0.989 Outlier Reg score : 0.919
# The outlier distance from the green line is : 21.91
# The outlier distance from the red line is : 22.06
# Regression slope : 1.991 Outlier Reg slope : 1.888
# Regression intercept : -0.837 Outlier Reg intercept : -1.394
# Regression score : 0.989 Outlier Reg score : 0.889
# The outlier distance from the green line is : 26.39
# The outlier distance from the red line is : 26.65
# Regression slope : 1.991 Outlier Reg slope : 1.833
# Regression intercept : -0.837 Outlier Reg intercept : -1.470
# Regression score : 0.989 Outlier Reg score : 0.855
# The outlier distance from the green line is : 30.86
# The outlier distance from the red line is : 31.22
# Regression slope : 1.991 Outlier Reg slope : 1.770
# Regression intercept : -0.837 Outlier Reg intercept : -1.538
# Regression score : 0.989 Outlier Reg score : 0.818
# The outlier distance from the green line is : 35.33
# The outlier distance from the red line is : 35.77
# Regression slope : 1.991 Outlier Reg slope : 1.701
# Regression intercept : -0.837 Outlier Reg intercept : -1.597
# Regression score : 0.989 Outlier Reg score : 0.779
# The outlier distance from the green line is : 39.80
# The outlier distance from the red line is : 40.26
# Regression slope : 1.991 Outlier Reg slope : 1.627
# Regression intercept : -0.837 Outlier Reg intercept : -1.647
# Regression score : 0.989 Outlier Reg score : 0.738
# The outlier distance from the green line is : 44.27
# The outlier distance from the red line is : 44.66
# Regression slope : 1.991 Outlier Reg slope : 1.550
# Regression intercept : -0.837 Outlier Reg intercept : -1.688
# Regression score : 0.989 Outlier Reg score : 0.697
# The outlier distance from the green line is : 48.75
# The outlier distance from the red line is : 48.96
# Regression slope : 1.991 Outlier Reg slope : 1.472
# Regression intercept : -0.837 Outlier Reg intercept : -1.721
# Regression score : 0.989 Outlier Reg score : 0.655
# The outlier distance from the green line is : 53.22
# The outlier distance from the red line is : 53.11

# %% [markdown]
# ### Conclusion
#
#
# The outlier pulls the line towards it. The further the outlier is from the line the stronger the pull, and the strong it's effect on the regression score.

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part4'></a>
#
# # Part 4 - Detection of outliers
# Outliers are the points most distant to the line, let's look at an example

# %% [markdown]
# ### Generating Data

# %%
## Lets generate some points

data = Data2D(s, 3)
X, y = data.generate_points(100)
plt.scatter(X[:,1],y)
plt.title('Data generated without outliers')
plt.show();

# %% [markdown]
# ### Adding outliers

# %%
## Adding 6 outliers
outliers = [(20,-10), (35,-30), (17,-17), (10,-30), (-5, -50), (15,-20)]
x_outliers = np.array([outliers[i][0] for i in range(len(outliers))])
y_outliers = np.array([outliers[i][1] for i in range(len(outliers))])

Xo = np.concatenate((X[:,1],x_outliers), axis=0)
yo = np.concatenate((y,y_outliers), axis=0)

plt.scatter(X[:,1],y)
plt.scatter(x_outliers,y_outliers, c='red', marker='x')
plt.title('Data generated with outliers')
plt.show();

# %% [markdown]
# We fit a regression line on points with and without outliers and see the effect, here we choose intentionally to  add outliers on the right side of the regression line to see clearly the effect.

# %%
a, b, c = regression(Xo.reshape(-1,1), yo)
a1, b1, c1 = regression(X[:,1].reshape(-1,1), y)
print('Regression slope : %.3f' % a1, 'Regression intercept : %.3f' % b1, 'Regression score : %.3f' % c1)
print('Outliers Regression slope : %.3f' % a, 'Outliers Regression intercept : %.3f' % b, 'Outliers Regression score : %.3f' % c)
plt.plot(Xo,a*Xo+b, c='red', label='Regression Line with outliers')
plt.plot(Xo,a1*Xo+b1, c='green', label='Regression Line without outliers')
plt.legend(loc='upper left')
plt.scatter(X[:,1],y)
plt.scatter(x_outliers,y_outliers, c='red', marker='x')
plt.title('Linear Regression fit on generated data with added outliers')
plt.show();
# Out:
# Regression slope : 2.027 Regression intercept : -1.114 Regression score : 0.988
# Outliers Regression slope : 1.256 Outliers Regression intercept : -2.919 Outliers Regression score : 0.424

# %%
## Checking distance of the points from the fitted line
### We use the line fitted with outliers supposing that we havent removed them yet

distances = []
for i in range(len(yo)):
    distance = np.absolute((a*Xo[i]+b-yo[i])/(np.sqrt(a**2+1)))
    distances.append(distance)

norms = [np.sqrt(x) for x in distances]
points = np.arange(len(yo))
plt.scatter(points[-6:], norms[-6:], c='red', label=' Outliers ')
plt.scatter(points[:-6], norms[:-6], label = 'Regular points ')
plt.legend()
plt.title('Scatter plot of distance of the points from the regression line')
plt.show();

# %%
The

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part4'></a>
#
# ### Part 4 - Metrics for defining an outlier
#
# We will say that a point is an outlier if it is located further than two standard deviations above or below the best-fit line  :
#
#
# <center> $\left | y-\widehat{y} \right |> 2 \sqrt{\frac{SSE}{n-2}}$ </center>
#
# With $n$ number of data points and SSE is sum of squared errors.
#
#
#
#
# Resources : (https://stats.libretexts.org/Bookshelves/Introductory_Statistics/Book%3A_Introductory_Statistics_(OpenStax)/12%3A_Linear_Regression_and_Correlation/12.07%3A_Outliers)

# %% [markdown]
# For the example before we compute $ s =  2 \sqrt{\frac{SSE}{n-2}}$ first.

# %% [markdown]
# Let's visualise the regression line fit along with the line limiting the boundary of outliers.

# %%
s = (-1,2)
X, y = generate_data(s, 2, 100)

## Adding one outlier
outliers = [(5,-5),(7,4)]
x_outliers = np.array([outliers[i][0] for i in range(len(outliers))])
y_outliers = np.array([outliers[i][1] for i in range(len(outliers))])
Xo = np.concatenate((X[:,1],x_outliers), axis=0)
yo = np.concatenate((y,y_outliers), axis=0)
plt.scatter(X[:,1],y)
plt.scatter(x_outliers,y_outliers, c='red', marker='x')
plt.title('Data generated with outliers')
plt.show();

# %%
a, b, c = regression(Xo.reshape(-1,1), yo)
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)
plt.plot(Xo,a*Xo+b, c='red')
plt.scatter(Xo[:-2],yo[:-2])
plt.scatter(Xo[-2:],yo[-2:], marker='x')
plt.title('Linear Regression fit on generated data with added outlier')
plt.show();
# Out:
# Regression slope : 1.968 Regression intercept : -1.486 Regression score : 0.982

# %%
## Lets compute s

squared_errors = [(a*Xo[i]+b-yo[i])**2 for i in range(len(yo))]

sse = sum(squared_errors)

s = np.sqrt(sse/(len(yo)-2))

print('s : %.2f' % s)
# Out:
# s : 2.25

# %%
## Lets plot the decision boundary for outliers

x = np.linspace(-20,20,50)
plt.plot(x,a*x+b, c='red', label='Regression line')
plt.plot(x,a*x+b+2*s, c='green', label = 'Boundary lines' , marker="_")
plt.plot(x,a*x+b-2*s, c='green', marker="_" )
plt.scatter(Xo[:-2],yo[:-2])
plt.scatter(Xo[-2:],yo[-2:], marker='x')
plt.title('Linear Regression fit and outlier boundaries')
plt.legend()
plt.show();

# %% [markdown]
# We can also detect outliers by computing the residual errors.

# %%
indices = []

for i in range(len(yo)) :
    if np.absolute(a*Xo[i]+b-yo[i]) > 2*s :
        indices.append(i)
        
print(indices)
# Out:
# [19, 100, 101]

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5'></a>
#
# ### Part 5 - Impact of number of outliers on the Regression

# %%
### Generating Data Points
s=(-1,2)
data = Data2D(s, 3)
X,y = data.generate_points(200)
title = '200 Points Generated '
plt.title(title)
plt.scatter(X[:,1],y);

# %%
## Fitting the regression line and printig the parameters
a, b, c = regression(X[:,1].reshape(-1,1), y)
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)
print('Original line slope : %.3f' % s[1], 'Original line intercept : %.3f' % s[0])

plt.plot(X,a*X+b, c='red')
title = 'Fitting a regression Line '
plt.title(title)
plt.scatter(X[:,1],y)
plt.show();
# Out:
# Regression slope : 1.995 Regression intercept : -1.019 Regression score : 0.991
# Original line slope : 2.000 Original line intercept : -1.000

# %%
## Defining a list of 20 outlier
outliers = [(0,-20), (0,19), (5,-20), (5,26), (-5, -28), (10,-20),(15,0),(-10,6),(3,-18),(-6,6),(-1,8),(-7,10),(-1,15),(-10,1),(-4,13),(-8,3),(5,-1),(13,-2),(15,3),(3,-12)]
x_outliers = np.array([outliers[i][0] for i in range(len(outliers))])
y_outliers = np.array([outliers[i][1] for i in range(len(outliers))])
Xo = np.concatenate((X[:,1],x_outliers), axis=0)
yo = np.concatenate((y,y_outliers), axis=0)
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)

plt.plot(X,a*X+b, c='red')
plt.scatter(X[:,1],y, c='blue')
plt.scatter(x_outliers,y_outliers, c='orange', marker='x')
plt.scatter(X[:,1],y)
title = 'Generated data and outliers'
plt.title(title)

plt.show();
# Out:
# Regression slope : 1.995 Regression intercept : -1.019 Regression score : 0.991

# %%
## We add each time one outlier and observe the effect
slopes = []
intercepts = []
scores = []

for i in range(1,len(outliers)+1):
    
    ## Adding i outlier
    x_outliers = np.array([outliers[j][0] for j in range(i)])
    y_outliers = np.array([outliers[j][1] for j in range(i)])
    Xo = np.concatenate((X[:,1],x_outliers), axis=0)
    yo = np.concatenate((y,y_outliers), axis=0)
    
    ## Fitting the regression line
    ao, bo, co = regression(Xo.reshape(-1,1), yo)
    print(f'After adding {i} outliers : ')
    print('Original line slope : %.3f' % s[1], ', Original line intercept : %.3f' % s[0])
    print('Original Regression slope : %.3f' % a, ', Outliers Regression slope : %.3f' % ao)
    print('Original Regression intercept : %.3f' % b, ', Outliers Regression intercept : %.3f' % bo)
    print('Original Regression score : %.3f' % c, ', Outliers Regression score : %.3f' % co)

    ## Appending the parameters to the lists
    slopes.append(ao)
    intercepts.append(bo)
    scores.append(co)
    
    ## Visualisation
    plt.scatter(X[:,1],y, c='blue')
    plt.scatter(x_outliers,y_outliers, c='orange', marker='x')
    plt.plot(X,a*X+b, c='red', label = 'Original Regression line')
    plt.plot(X,ao*X+bo, c='green', label = 'Outliers Regression line')
    plt.scatter(X[:,1],y)
    title = f'Regression visualisation of outliers after adding {i} outliers'
    plt.title(title)
    plt.legend()
    plt.show();
# Out:
# After adding 1 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.996
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.114
# Original Regression score : 0.991 , Outliers Regression score : 0.985
# After adding 2 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.995
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.014
# Original Regression score : 0.991 , Outliers Regression score : 0.979
# After adding 3 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.988
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.150
# Original Regression score : 0.991 , Outliers Regression score : 0.967
# After adding 4 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.992
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.069
# Original Regression score : 0.991 , Outliers Regression score : 0.962
# After adding 5 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.998
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.158
# Original Regression score : 0.991 , Outliers Regression score : 0.959
# After adding 6 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.977
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.325
# Original Regression score : 0.991 , Outliers Regression score : 0.937
# After adding 7 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.952
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.438
# Original Regression score : 0.991 , Outliers Regression score : 0.925
# After adding 8 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.935
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.291
# Original Regression score : 0.991 , Outliers Regression score : 0.915
# After adding 9 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.932
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.396
# Original Regression score : 0.991 , Outliers Regression score : 0.908
# After adding 10 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.924
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.298
# Original Regression score : 0.991 , Outliers Regression score : 0.902
# After adding 11 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.923
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.243
# Original Regression score : 0.991 , Outliers Regression score : 0.901
# After adding 12 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.911
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.116
# Original Regression score : 0.991 , Outliers Regression score : 0.892
# After adding 13 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.909
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.030
# Original Regression score : 0.991 , Outliers Regression score : 0.888
# After adding 14 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.895
# Original Regression intercept : -1.019 , Outliers Regression intercept : -0.920
# Original Regression score : 0.991 , Outliers Regression score : 0.881
# After adding 15 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.889
# Original Regression intercept : -1.019 , Outliers Regression intercept : -0.814
# Original Regression score : 0.991 , Outliers Regression score : 0.875
# After adding 16 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.879
# Original Regression intercept : -1.019 , Outliers Regression intercept : -0.719
# Original Regression score : 0.991 , Outliers Regression score : 0.870
# After adding 17 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.877
# Original Regression intercept : -1.019 , Outliers Regression intercept : -0.762
# Original Regression score : 0.991 , Outliers Regression score : 0.868
# After adding 18 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.859
# Original Regression intercept : -1.019 , Outliers Regression intercept : -0.864
# Original Regression score : 0.991 , Outliers Regression score : 0.859
# After adding 19 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.839
# Original Regression intercept : -1.019 , Outliers Regression intercept : -0.955
# Original Regression score : 0.991 , Outliers Regression score : 0.850
# After adding 20 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 1.995 , Outliers Regression slope : 1.837
# Original Regression intercept : -1.019 , Outliers Regression intercept : -1.029
# Original Regression score : 0.991 , Outliers Regression score : 0.847

# %%
# Visualisation of regression parameters
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
plt.figure(figsize=(20, 20), dpi=80)
fig.tight_layout()


x = np.arange(20)+1

ax1.plot(x, slopes)
ax2.plot(x, intercepts)
ax3.plot(x, scores)

ax1.set_title('Regression slope')
ax2.set_title('Regression intercept')
ax3.set_title('Regression score')

ax1.set_xlabel('Number of outliers added')
ax2.set_xlabel('Number of outliers added')
ax3.set_xlabel('Number of outliers added')


plt.show();

# %% [markdown]
# ## Implementing knowledge of outliers on the dataset

# %% [markdown]
# ###  Detecting Outliers

# %%
import os
import pandas as pd
import numpy as np
path = "."
filename = os.path.join("auto-mpg.csv")
df = pd.read_csv(filename)

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
# 5  15.0          8         429.0        198    4341          10.0    70
# 6  14.0          8         454.0        220    4354           9.0    70
# 7  14.0          8         440.0        215    4312           8.5    70
# 8  14.0          8         455.0        225    4425          10.0    70
# 9  15.0          8         390.0        190    3850           8.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 5       1           ford galaxie 500
# 6       1           chevrolet impala
# 7       1          plymouth fury iii
# 8       1           pontiac catalina
# 9       1         amc ambassador dpl

# %%
new_df = df.copy()
new_df = new_df.select_dtypes(include=["int","float"])

headers = list(new_df.columns.values)
fields = []
for field in headers:
    fields.append({
        "name":field,
        "mean":df[field].mean(),
        "var":df[field].var(),
        "sdev":df[field].std(),
        "max": df[field].max()
    })
for field in fields:
    print(field)
# Out:
# {'name': 'mpg', 'mean': 23.514572864321615, 'var': 61.089610774274405, 'sdev': 7.815984312565782, 'max': 46.6}
# {'name': 'cylinders', 'mean': 5.454773869346734, 'var': 2.8934154399199943, 'sdev': 1.7010042445332094, 'max': 8}
# {'name': 'displacement', 'mean': 193.42587939698493, 'var': 10872.199152247364, 'sdev': 104.26983817119581, 'max': 455.0}
# {'name': 'weight', 'mean': 2970.424623115578, 'var': 717140.9905256768, 'sdev': 846.8417741973271, 'max': 5140}
# {'name': 'acceleration', 'mean': 15.568090452261291, 'var': 7.604848233611381, 'sdev': 2.7576889298126757, 'max': 24.8}
# {'name': 'year', 'mean': 76.01005025125629, 'var': 13.672442818627143, 'sdev': 3.697626646732623, 'max': 82}
# {'name': 'origin', 'mean': 1.5728643216080402, 'var': 0.6432920268850575, 'sdev': 0.8020548777266163, 'max': 3}

# %% [markdown]
# Z score = (x -mean) / std. deviation

# %%
threshold = 2
outlier = []
for i in df["displacement"]:
    z = (i-df["displacement"].mean())/df["displacement"].std()
    if z > threshold:
        outlier.append(i)
print('outlier in dataset is', outlier)
# Out:
# outlier in dataset is [429.0, 454.0, 440.0, 455.0, 455.0, 429.0, 429.0, 440.0, 455.0]

# %%
threshold = 2
outlier = []
for i in df["weight"]:
    z = (i-df["weight"].mean())/df["weight"].std()
    if z > threshold:
        outlier.append(i)
print('outlier in dataset is', outlier)
# Out:
# outlier in dataset is [4732, 4955, 4746, 5140, 4952, 4735, 4951, 4997, 4906, 4699, 4668]

# %%
threshold = 2
outlier = []
for i in df["mpg"]:
    z = (i-df["mpg"].mean())/df["mpg"].std()
    if z > threshold:
        outlier.append(i)
print('outlier in dataset is', outlier)
# Out:
# outlier in dataset is [43.1, 39.4, 41.5, 46.6, 40.8, 44.3, 43.4, 44.6, 40.9, 44.0]

# %%
threshold = 2
outlier = []
for i in df["acceleration"]:
    z = (i-df["acceleration"].mean())/df["acceleration"].std()
    if z > threshold:
        outlier.append(i)
print('outlier in dataset is', outlier)
# Out:
# outlier in dataset is [23.5, 22.2, 22.1, 21.9, 21.5, 24.8, 22.2, 21.7, 23.7, 21.8, 24.6]

# %% [markdown]
# Conclusion: all the outliers are close to the maximum value of the feauture.

# %% [markdown]
# ## Resources
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html
#
#
#
#
# https://stackoverflow.com/questions/17725927/boxplots-in-matplotlib-markers-and-outliers
#
#
#
# https://matplotlib.org/stable/gallery/pyplots/boxplot_demo_pyplot.html

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df["weight"], notch =False, sym = '+', vert=False, whis=0.5,
          positions=None, widths=None, patch_artist=False,
        bootstrap=None, usermedians=None, conf_intervals=None)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3fbb0bfd0>,
#   <matplotlib.lines.Line2D at 0x1d3fbb28340>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d3fbb286d0>,
#   <matplotlib.lines.Line2D at 0x1d3fbb28a60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3fbb0bbe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3fbb28df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3fbb341c0>],
#  'means': []}

# %%
plt.boxplot(df["displacement"], notch =False, sym = '+', vert=False, whis=1,
          positions=None, widths=None, patch_artist=False,
        bootstrap=None, usermedians=None, conf_intervals=None)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3fbc10e80>,
#   <matplotlib.lines.Line2D at 0x1d3fbc22250>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d3fbc225e0>,
#   <matplotlib.lines.Line2D at 0x1d3fbc22970>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3fbc10af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3fbc22d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3fbc300d0>],
#  'means': []}

# %%
plt.boxplot(df["acceleration"], notch =False, sym = '+', vert=False, whis=1,
          positions=None, widths=None, patch_artist=False,
        bootstrap=None, usermedians=None, conf_intervals=None)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3fbc89e50>,
#   <matplotlib.lines.Line2D at 0x1d3fbc98220>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d3fbc985b0>,
#   <matplotlib.lines.Line2D at 0x1d3fbc98940>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3fbc89ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3fbc98cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3fbca50a0>],
#  'means': []}

# %%
plt.boxplot(df["mpg"], notch =False, sym = '+', vert=False, whis=1,
          positions=None, widths=None, patch_artist=False,
        bootstrap=None, usermedians=None, conf_intervals=None)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3fbd02490>,
#   <matplotlib.lines.Line2D at 0x1d3fbd02820>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d3fbd02be0>,
#   <matplotlib.lines.Line2D at 0x1d3fbd02f70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3fbd02100>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3fbd0e340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3fbd0e6d0>],
#  'means': []}

# %% [markdown]
# ### Removing Outliers from the dataset

# %%
df['zscore_weight'] = (df.weight - df.weight.mean() ) / df.weight.std()

# %%
df['zscore_mpg'] = (df.mpg - df.mpg.mean() ) / df.mpg.std()

# %%
df['zscore_acceleration'] = ( df.acceleration - df.acceleration.mean() ) / df.acceleration.std()

# %%
df['zscore_displacement'] = ( df.displacement - df.displacement.mean() ) / df.displacement.std()

# %% [markdown]
# https://statisticsbyjim.com/basics/outliers/

# %%
df[df['zscore_displacement']>-2 | (df['zscore_displacement']<2)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 289  16.9          8         350.0        155    4360          14.9    79
# 290  15.5          8         351.0        142    4054          14.3    79
# 292  18.5          8         360.0        150    3940          13.0    79
# 298  23.0          8         350.0        125    3900          17.4    79
# 364  26.6          8         350.0        105    3725          19.0    81
#
#      origin                                  name  zscore_weight  zscore_mpg  \
# 0         1             chevrolet chevelle malibu       0.630077   -0.705551
# 1         1                     buick skylark 320       0.853259   -1.089379
# 2         1                    plymouth satellite       0.549778   -0.705551
# 3         1                         amc rebel sst       0.546236   -0.961437
# 4         1                           ford torino       0.565130   -0.833494
# ..      ...                                   ...            ...         ...
# 289       1               buick estate wagon (sw)       1.640891   -0.846288
# 290       1              ford country squire (sw)       1.279549   -1.025408
# 292       1  chrysler lebaron town @ country (sw)       1.144931   -0.641579
# 298       1                     cadillac eldorado       1.097697   -0.065836
# 364       1                 oldsmobile cutlass ls       0.891046    0.394759
#
#      zscore_acceleration  zscore_displacement
# 0              -1.293870             1.089233
# 1              -1.475181             1.501624
# 2              -1.656492             1.194728
# 3              -1.293870             1.060461
# 4              -1.837804             1.041280
# ..                   ...                  ...
# 289            -0.242265             1.501624
# 290            -0.459838             1.511215
# 292            -0.931247             1.597529
# 298             0.664292             1.501624
# 364             1.244488             1.501624
#
# [98 rows x 13 columns]

# %%
df[df['zscore_acceleration']>-2 | (df['zscore_acceleration']<2)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 19   26.0          4          97.0         46    1835          20.5    70
# 28    9.0          8         304.0        193    4732          18.5    70
# 32   25.0          4          98.0          ?    2046          19.0    71
# 46   22.0          4         140.0         72    2408          19.0    71
# 51   30.0          4          79.0         70    2074          19.5    71
# ..    ...        ...           ...        ...     ...           ...   ...
# 368  27.0          4         112.0         88    2640          18.6    82
# 374  23.0          4         151.0          ?    3035          20.5    82
# 394  44.0          4          97.0         52    2130          24.6    82
# 396  28.0          4         120.0         79    2625          18.6    82
# 397  31.0          4         119.0         82    2720          19.4    82
#
#      origin                          name  zscore_weight  zscore_mpg  \
# 19        2  volkswagen 1131 deluxe sedan      -1.340775    0.317993
# 28        1                      hi 1200d       2.080171   -1.857037
# 32        1                    ford pinto      -1.091614    0.190050
# 46        1           chevrolet vega (sw)      -0.664144   -0.193779
# 51        2                   peugeot 304      -1.058550    0.829765
# ..      ...                           ...            ...         ...
# 368       1      chevrolet cavalier wagon      -0.390185    0.445936
# 374       1                amc concord dl       0.076254   -0.065836
# 394       2                     vw pickup      -0.992422    2.620966
# 396       1                   ford ranger      -0.407897    0.573879
# 397       1                    chevy s-10      -0.295716    0.957708
#
#      zscore_acceleration  zscore_displacement
# 19              1.788421            -0.924773
# 28              1.063176             1.060461
# 32              1.244488            -0.915182
# 46              1.244488            -0.512381
# 51              1.425799            -1.097402
# ..                   ...                  ...
# 368             1.099439            -0.780915
# 374             1.788421            -0.406885
# 394             3.275173            -0.924773
# 396             1.099439            -0.704191
# 397             1.389537            -0.713781
#
# [62 rows x 13 columns]

# %%
df[df['zscore_mpg']<-2 | (df['zscore_mpg']>2)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 389  22.0          6         232.0        112    2835          14.7    82
# 392  27.0          4         151.0         90    2950          17.3    82
# 393  27.0          4         140.0         86    2790          15.6    82
# 396  28.0          4         120.0         79    2625          18.6    82
# 397  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name  zscore_weight  zscore_mpg  \
# 0         1  chevrolet chevelle malibu       0.630077   -0.705551
# 1         1          buick skylark 320       0.853259   -1.089379
# 2         1         plymouth satellite       0.549778   -0.705551
# 3         1              amc rebel sst       0.546236   -0.961437
# 4         1                ford torino       0.565130   -0.833494
# ..      ...                        ...            ...         ...
# 389       1             ford granada l      -0.159917   -0.193779
# 392       1           chevrolet camaro      -0.024119    0.445936
# 393       1            ford mustang gl      -0.213056    0.445936
# 396       1                ford ranger      -0.407897    0.573879
# 397       1                 chevy s-10      -0.295716    0.957708
#
#      zscore_acceleration  zscore_displacement
# 0              -1.293870             1.089233
# 1              -1.475181             1.501624
# 2              -1.656492             1.194728
# 3              -1.293870             1.060461
# 4              -1.837804             1.041280
# ..                   ...                  ...
# 389            -0.314789             0.369945
# 392             0.628029            -0.406885
# 393             0.011571            -0.512381
# 396             1.099439            -0.704191
# 397             1.389537            -0.713781
#
# [325 rows x 13 columns]

# %%
df[df['zscore_weight']>-2 | (df['zscore_weight']<2)]
#df.head(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 5    15.0          8         429.0        198    4341          10.0    70
# 6    14.0          8         454.0        220    4354           9.0    70
# 7    14.0          8         440.0        215    4312           8.5    70
# 8    14.0          8         455.0        225    4425          10.0    70
# 9    15.0          8         390.0        190    3850           8.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 288  18.2          8         318.0        135    3830          15.2    79
# 289  16.9          8         350.0        155    4360          14.9    79
# 290  15.5          8         351.0        142    4054          14.3    79
# 292  18.5          8         360.0        150    3940          13.0    79
# 298  23.0          8         350.0        125    3900          17.4    79
#
#      origin                                  name  zscore_weight  zscore_mpg  \
# 5         1                      ford galaxie 500       1.618455   -1.089379
# 6         1                      chevrolet impala       1.633806   -1.217322
# 7         1                     plymouth fury iii       1.584210   -1.217322
# 8         1                      pontiac catalina       1.717647   -1.217322
# 9         1                    amc ambassador dpl       1.038654   -1.089379
# ..      ...                                   ...            ...         ...
# 288       1                       dodge st. regis       1.015037   -0.679962
# 289       1               buick estate wagon (sw)       1.640891   -0.846288
# 290       1              ford country squire (sw)       1.279549   -1.025408
# 292       1  chrysler lebaron town @ country (sw)       1.144931   -0.641579
# 298       1                     cadillac eldorado       1.097697   -0.065836
#
#      zscore_acceleration  zscore_displacement
# 5              -2.019115             2.259274
# 6              -2.381737             2.499036
# 7              -2.563048             2.364769
# 8              -2.019115             2.508627
# 9              -2.563048             1.885244
# ..                   ...                  ...
# 288            -0.133478             1.194728
# 289            -0.242265             1.501624
# 290            -0.459838             1.511215
# 292            -0.931247             1.597529
# 298             0.664292             1.501624
#
# [80 rows x 13 columns]

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part6'></a>
#
# ### Part 6 -  Conclusion :
#
# The regression slopes may or may not change strongly, it depends on the positions of the outliers, if 2 outliers are symetric with respect to the regression line then their effect on the slope cancels out.
#
# Adding outliers always affect the regression score and make it smaller
