# %%
import numpy as np
import math
from abc import ABC, abstractmethod
from numpy.random import default_rng
import matplotlib.pyplot as plt
rng = default_rng()
from sklearn.utils import shuffle
from sklearn.linear_model import LinearRegression

# %%
## Generate data points
class Line3D:
    
    def __init__(self, line_parameters = (2, 4, -1), noise_variance = 1 ):
        
        # intialize member variables here 
        self.line_parameters = line_parameters
        self.noise_variance = noise_variance
        
    def generate_points(self, N):

        # Generate N points
        # Adding the X_0 coordinates full of ones cost us nothing, but will allow us to use vector notation and calculation. 
        
        X_0 = np.ones(N)
        
        # here you have to generate random numbers through uniform distribution 
        # for X_1 and X_2, range is required which is specified in the exercise discription 
        X_1 = 20*(np.random.random(N)-0.5)
        X_2 = 20*(np.random.random(N)-0.5)
        
        # initialize epsilon 
        epsilon = rng.normal(0, self.noise_variance**(1/2), N)
        
        # initialize **y** with the equation of line here. Equation of line is written in the desciption above, 
        # line parameters (a,b, c) are stored in a local variable
        
        y = self.line_parameters[0]*X_1 + self.line_parameters[1]*X_2 + self.line_parameters[2] + epsilon
        
         # We create a design matrix, where rows are datapoints and columns are features, or input dimensions
        X = np.vstack( [X_0, X_1, X_2]).transpose()
        
    
        # return points here
        return X, y
        
    def generate_dataset(self, N, train_ratio = 0.6):
        
        # generate train and test data points, and store in member variables 
        self.X_train , self.y_train = self.generate_points( int(train_ratio*N) )
      
        self.X_test , self.y_test = self.generate_points( N-int(train_ratio*N) )
        
    def get_minibatches_train(self, M):
        
        # pick random points in the training set
        
        size_split = int(len(self.X_train)/M)
        
        X_minibatch = []
        y_minibatch = []
        
        X_train_shuffled, y_train_shuffled = shuffle(self.X_train, self.y_train)
        
        # run a loop and 'extract' data in chunks (batches)
        for i in range(M):
            # extract x and y mini batch from training data
            x_mini = X_train_shuffled[(i*size_split):((i+1)*size_split),:]
            y_mini = y_train_shuffled[(i*size_split):((i+1)*size_split)]
            
            # append the extracted data to X_minibatch and y_minibatch
            X_minibatch.append(x_mini)
            y_minibatch.append(y_mini)
        
        
        return X_minibatch, y_minibatch
    
    def plot( self, X, y, additional_line_parameters = None ):
        
        fig = plt.figure(figsize=(10,10))
        ax = fig.add_subplot(111, projection='3d')
        
        ax.scatter(X[:, 1], X[:, 2], y, marker = '.')
        
        X_1 = np.linspace(-10, 10, 2)
        X_2 = np.linspace(-10, 10, 2)

        X_1, X_2 = np.meshgrid(X_1, X_2)
        
        if additional_line_parameters is not None:
            theta_0, theta_1, theta_2 = additional_line_parameters
        else:
            theta_0, theta_1, theta_2 = self.line_parameters
        
        y = theta_0 + X_1 * theta_1 + X_2 * theta_2
    
        ax.plot_surface(X_1, X_2, y, alpha = 0.4, color='g')
        
        
data = Line3D( line_parameters=(1,2,3), noise_variance=10 )
print(data.line_parameters)
X_vis, y_vis = data.generate_points(1000)
# Out:
# (1, 2, 3)

# %% [markdown]
# # Generate Data
# ## Scatter plot
# ## Scatter residual plot
# ## Check Leverage points video

# %%
def generate_data(slope = (1,1), noise_variance=1, N = 50):
    
    # initialize noise epsilon 
    epsilon = rng.normal(0, noise_variance**(1/2), N)
    
    ## Generate N points
    
    # Adding the X_0 coordinates full of ones for vector multiplications
    X_0 = np.ones(N)
    # for X_1 generate random points between -15,15
    X_1 = 30*(np.random.random(N)-0.5)
    
    # We create a design matrix, where rows are datapoints and columns are features, or input dimensions
    X = np.vstack( [X_0, X_1]).transpose()
    
    # initialize **y** with the equation of line here. Equation of line is written in the desciption above, 
    # line parameters (a,b, c) are stored in a local variable

    y = X.dot(np.array(slope)) + epsilon
    
    return X, y

# %%
def regression(X, y) :
    reg = LinearRegression().fit(X.reshape(-1,1), y)
    
    return reg.coef_[0], reg.intercept_, reg.score(X, y)

# %%
X, y = generate_data((-1,2), 4, 100)
a, b, c = regression(X[:,1].reshape(-1,1), y)
plt.plot(X[:,1],a*X[:,1]+b, c='red')
plt.scatter(X[:,1],y)
plt.show();

# %%
print(a, b, c)
# Out:
# 1.966957225142455 -1.1339881535047 0.9879220597317754

# %%
outlier = (20,0)
Xo = np.append(X[:,1],outlier[0])
yo = np.append(y,outlier[1])
yo.shape
# Out:
# (101,)

# %%
a, b, c = regression(Xo.reshape(-1,1), yo)
plt.plot(Xo,a*Xo+b, c='red')
plt.scatter(Xo,yo)
plt.show();

# %%
    print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)
# Out:
# Regression slope : 1.872 Regression intercept : -1.500 Regression score : 0.942

# %%
slopes = []
intercepts = []
reg_score = []
for i in range(20):
    outlier = (-15+2*i, -30)
    Xo = np.append(X[:,1],outlier[0])
    yo = np.append(y,outlier[1])
    a, b, c = regression(Xo.reshape(-1,1), yo)
    slopes.append(a)
    intercepts.append(b)
    reg_score.append(c)
    print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)
    print('The outlier is :', outlier)
    z = np.ones(len(y)+1)
    z[len(y)] = 0
    plt.plot(Xo,a*Xo+b, c='red', label = f'Regression line of {outlier} ', alpha = 0.7)
    plt.scatter(Xo[:len(y)],yo[:len(y)], marker = 'o', cmap='Spectral', alpha = 0.6 )
    plt.scatter(Xo[len(y)],yo[len(y)], marker = 'x', cmap='summer' )
    plt.show();
# Out:
# Regression slope : 1.966 Regression intercept : -1.128 Regression score : 0.988
# The outlier is : (-15, -30)
# Regression slope : 1.972 Regression intercept : -1.166 Regression score : 0.988
# The outlier is : (-13, -30)
# Regression slope : 1.977 Regression intercept : -1.204 Regression score : 0.987
# The outlier is : (-11, -30)
# Regression slope : 1.980 Regression intercept : -1.242 Regression score : 0.984
# The outlier is : (-9, -30)
# Regression slope : 1.981 Regression intercept : -1.282 Regression score : 0.981
# The outlier is : (-7, -30)
# Regression slope : 1.979 Regression intercept : -1.321 Regression score : 0.976
# The outlier is : (-5, -30)
# Regression slope : 1.976 Regression intercept : -1.360 Regression score : 0.971
# The outlier is : (-3, -30)
# Regression slope : 1.970 Regression intercept : -1.400 Regression score : 0.965
# The outlier is : (-1, -30)
# Regression slope : 1.963 Regression intercept : -1.440 Regression score : 0.957
# ...
