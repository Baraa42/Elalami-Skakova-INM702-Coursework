# %% [markdown]
# ## Introduction
# Outliers are the point most distant to the regression line. Their location can bedetected by plotting a visual representation and by performing certain calculations like standarddeviation. Outlier’s distance from the regression line is calculated as follows: $\left | y-\widehat{y} \right |> 2 \sqrt{\frac{SSE}{n-2}}$, where n is the number of data points, SSE is the sum of squared errors, y is the true value and y hat is the prediction.This facilitates its detection. For example, in a  2-dimensionalspace, a point P will be considered an outlier if it is not between D-2s and D+2s, where Dis the regression line and $\ s = \sqrt{\frac{SSE}{n-2}}$. We use this characteristic of an outlier as a basis to initiate the function with the input values quantity outliers and number of generated points.

# %%
import numpy as np
import math
from abc import ABC, abstractmethod
from numpy.random import default_rng
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.linear_model import LinearRegression

# %%
rng = default_rng(seed=0)

# %% [markdown]
# # Generating  Data

# %%
## Generate data points
class Data2D:
    
    def __init__(self, slope = (1, 1), noise_variance = 1 ):
        
        # intialize member variables here 
        self.slope = slope
        self.noise_variance = noise_variance
        
        
        
    def generate_points(self, N = 50):
    
        slope = self.slope
        noise_variance = self.noise_variance

        # initialize noise epsilon 
        epsilon = rng.normal(0, noise_variance**(1/2), N)

        ## Generate N points

        # Adding the X_0 coordinates full of ones for vector multiplications
        X_0 = np.ones(N)
        # for X_1 generate random points between -15,15
        X_1 = 30*(np.random.random(N)-0.5)

        # We create a design matrix, where rows are datapoints and columns are features, or input dimensions
        X = np.vstack( [X_0, X_1]).transpose()

        # initialize **y** with the equation of line here. Equation of line is written in the desciption above, 
        # line parameters (a,b, c) are stored in a local variable

        y = X.dot(np.array(slope)) + epsilon

        return X, y

# %% [markdown]
# ## Scatter plot
# ## Scatter residual plot
# ## Check Leverage points video

# %%
def generate_data(slope = (1,1), noise_variance=1, N = 50):
    
    # initialize noise epsilon 
    epsilon = rng.normal(0, noise_variance**(1/2), N)
    
    ## Generate N points
    
    # Adding the X_0 coordinates full of ones for vector multiplications
    X_0 = np.ones(N)
    # for X_1 generate random points between -15,15
    X_1 = 30*(np.random.random(N)-0.5)
    
    # We create a design matrix, where rows are datapoints and columns are features, or input dimensions
    X = np.vstack( [X_0, X_1]).transpose()
    
    # initialize **y** with the equation of line here. Equation of line is written in the desciption above, 
    # line parameters (a,b, c) are stored in a local variable

    y = X.dot(np.array(slope)) + epsilon
    
    return X, y

# %%
def regression(X, y) :
    reg = LinearRegression().fit(X.reshape(-1,1), y)
    
    return reg.coef_[0], reg.intercept_, reg.score(X, y)

# %%
s = (-1,2)
X, y = generate_data(s, 4, 100)
ar, br, cr = regression(X[:,1].reshape(-1,1), y)
print('Regression slope : %.3f' % ar, 'Regression intercept : %.3f' % br, 'Regression score : %.3f' % cr)
plt.plot(X[:,1],ar*X[:,1]+br, c='red')
plt.scatter(X[:,1],y)
plt.title('Linear Regression fit on generated data')
plt.show();
# Out:
# Regression slope : 1.993 Regression intercept : -0.832 Regression score : 0.988

# %%
## Adding one outlier
outlier = (20,0)
Xo = np.append(X[:,1],outlier[0])
yo = np.append(y,outlier[1])

# %%
a, b, c = regression(Xo.reshape(-1,1), yo)
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)
plt.plot(Xo,a*Xo+b, c='red')
plt.scatter(Xo,yo)
plt.title('Linear Regression fit on generated data with added outlier')

plt.show();
# Out:
# Regression slope : 1.904 Regression intercept : -1.123 Regression score : 0.943

# %%
## Studying the impact of adding one outlier on randomly generated data with one outlier
## Each time we change the outlier and see what happens
slopes = []
intercepts = []
reg_score = []
distances = []
for i in range(100):
    outlier = (-50+i, -30)
    Xo = np.append(X[:,1],outlier[0])
    yo = np.append(y,outlier[1])
    slope, intercept, score = regression(Xo.reshape(-1,1), yo)
    slopes.append(slope)
    intercepts.append(intercept)
    reg_score.append(score)
    a = s[1]
    b = s[0]
    distance = np.absolute((a*outlier[0]+b-outlier[1])/(np.sqrt(a**2+1)))
    distance_reg = np.absolute((slope*outlier[0]+intercept-outlier[1])/(np.sqrt(slope**2+1)))
    distances.append(distance)
    if i%5 == 0 :
        print('Regression slope : %.3f' % ar,'Outlier Reg slope : %.3f' % slope)  
        print('Regression intercept : %.3f' % br,'Outlier Reg intercept : %.3f' % intercept)
        print('Regression score : %.3f' % cr,'Outlier Reg score : %.3f' % score)
        print('The outlier distance from the green line is : %.2f' % distance)
        print('The outlier distance from the red line is : %.2f' % distance_reg)
        z = np.ones(len(y)+1)
        z[len(y)] = 0
        plt.plot(Xo,slope*Xo+intercept, c='red', label = f'Regression line with outilier :  {outlier} ', alpha = 0.7)
        plt.plot(Xo,a*Xo+b, c='green', label = f'Original Line', alpha = 0.7)
        plt.scatter(Xo[:len(y)],yo[:len(y)], marker = 'o', cmap='Spectral', alpha = 0.6 )
        plt.scatter(Xo[len(y)],yo[len(y)], marker = 'x', cmap='summer')
        plt.legend(loc = 'upper left')
        plt.show();
# Out:
# Regression slope : 1.993 Outlier Reg slope : 1.656
# Regression intercept : -0.832 Outlier Reg intercept : -0.007
# Regression score : 0.988 Outlier Reg score : 0.876
# The outlier distance from the green line is : 31.75
# The outlier distance from the red line is : 27.29
# Regression slope : 1.993 Outlier Reg slope : 1.719
# Regression intercept : -0.832 Outlier Reg intercept : -0.116
# Regression score : 0.988 Outlier Reg score : 0.902
# The outlier distance from the green line is : 27.28
# The outlier distance from the red line is : 23.88
# Regression slope : 1.993 Outlier Reg slope : 1.780
# Regression intercept : -0.832 Outlier Reg intercept : -0.230
# Regression score : 0.988 Outlier Reg score : 0.925
# The outlier distance from the green line is : 22.81
# The outlier distance from the red line is : 20.30
# Regression slope : 1.993 Outlier Reg slope : 1.837
# Regression intercept : -0.832 Outlier Reg intercept : -0.348
# Regression score : 0.988 Outlier Reg score : 0.946
# The outlier distance from the green line is : 18.34
# The outlier distance from the red line is : 16.56
# Regression slope : 1.993 Outlier Reg slope : 1.888
# Regression intercept : -0.832 Outlier Reg intercept : -0.468
# Regression score : 0.988 Outlier Reg score : 0.964
# The outlier distance from the green line is : 13.86
# The outlier distance from the red line is : 12.69
# Regression slope : 1.993 Outlier Reg slope : 1.932
# Regression intercept : -0.832 Outlier Reg intercept : -0.589
# Regression score : 0.988 Outlier Reg score : 0.977
# The outlier distance from the green line is : 9.39
# The outlier distance from the red line is : 8.68
# Regression slope : 1.993 Outlier Reg slope : 1.967
# Regression intercept : -0.832 Outlier Reg intercept : -0.708
# Regression score : 0.988 Outlier Reg score : 0.986
# The outlier distance from the green line is : 4.92
# The outlier distance from the red line is : 4.55
# Regression slope : 1.993 Outlier Reg slope : 1.992
# Regression intercept : -0.832 Outlier Reg intercept : -0.824
# Regression score : 0.988 Outlier Reg score : 0.989
# The outlier distance from the green line is : 0.45
# The outlier distance from the red line is : 0.31
# Regression slope : 1.993 Outlier Reg slope : 2.005
# Regression intercept : -0.832 Outlier Reg intercept : -0.933
# Regression score : 0.988 Outlier Reg score : 0.986
# The outlier distance from the green line is : 4.02
# The outlier distance from the red line is : 4.02
# Regression slope : 1.993 Outlier Reg slope : 2.007
# Regression intercept : -0.832 Outlier Reg intercept : -1.033
# Regression score : 0.988 Outlier Reg score : 0.978
# The outlier distance from the green line is : 8.50
# The outlier distance from the red line is : 8.44
# Regression slope : 1.993 Outlier Reg slope : 1.996
# Regression intercept : -0.832 Outlier Reg intercept : -1.123
# Regression score : 0.988 Outlier Reg score : 0.963
# The outlier distance from the green line is : 12.97
# The outlier distance from the red line is : 12.93
# Regression slope : 1.993 Outlier Reg slope : 1.973
# Regression intercept : -0.832 Outlier Reg intercept : -1.201
# Regression score : 0.988 Outlier Reg score : 0.943
# The outlier distance from the green line is : 17.44
# The outlier distance from the red line is : 17.48
# Regression slope : 1.993 Outlier Reg slope : 1.938
# Regression intercept : -0.832 Outlier Reg intercept : -1.264
# Regression score : 0.988 Outlier Reg score : 0.917
# The outlier distance from the green line is : 21.91
# The outlier distance from the red line is : 22.06
# Regression slope : 1.993 Outlier Reg slope : 1.892
# Regression intercept : -0.832 Outlier Reg intercept : -1.313
# Regression score : 0.988 Outlier Reg score : 0.886
# The outlier distance from the green line is : 26.39
# The outlier distance from the red line is : 26.67
# Regression slope : 1.993 Outlier Reg slope : 1.836
# Regression intercept : -0.832 Outlier Reg intercept : -1.347
# Regression score : 0.988 Outlier Reg score : 0.852
# The outlier distance from the green line is : 30.86
# The outlier distance from the red line is : 31.27
# Regression slope : 1.993 Outlier Reg slope : 1.772
# Regression intercept : -0.832 Outlier Reg intercept : -1.367
# Regression score : 0.988 Outlier Reg score : 0.814
# The outlier distance from the green line is : 35.33
# The outlier distance from the red line is : 35.84
# Regression slope : 1.993 Outlier Reg slope : 1.702
# Regression intercept : -0.832 Outlier Reg intercept : -1.372
# Regression score : 0.988 Outlier Reg score : 0.774
# The outlier distance from the green line is : 39.80
# The outlier distance from the red line is : 40.37
# Regression slope : 1.993 Outlier Reg slope : 1.626
# Regression intercept : -0.832 Outlier Reg intercept : -1.365
# Regression score : 0.988 Outlier Reg score : 0.732
# The outlier distance from the green line is : 44.27
# The outlier distance from the red line is : 44.81
# Regression slope : 1.993 Outlier Reg slope : 1.548
# Regression intercept : -0.832 Outlier Reg intercept : -1.346
# Regression score : 0.988 Outlier Reg score : 0.689
# The outlier distance from the green line is : 48.75
# The outlier distance from the red line is : 49.15
# Regression slope : 1.993 Outlier Reg slope : 1.468
# Regression intercept : -0.832 Outlier Reg intercept : -1.317
# Regression score : 0.988 Outlier Reg score : 0.647
# The outlier distance from the green line is : 53.22
# The outlier distance from the red line is : 53.34

# %% [markdown]
# ## Conclusion :
#
# The outlier pulls the line towards it. The further the outlier is from the line the stronger the pull, and the strong it's effect on the regression score.

# %% [markdown]
# # How to detect outliers ?
#
# Outliers are the points most distant to the line, let's look at an example

# %% [markdown]
# ### Generating Data

# %%
## Lets generate some points

data = Data2D(s, 3)
X, y = data.generate_points(100)
plt.scatter(X[:,1],y)
plt.title('Data generated without outliers')
plt.show();

# %% [markdown]
# ### Adding outliers

# %%
## Adding 6 outliers
outliers = [(20,-10), (35,-30), (17,-17), (10,-30), (-5, -50), (15,-20)]
x_outliers = np.array([outliers[i][0] for i in range(len(outliers))])
y_outliers = np.array([outliers[i][1] for i in range(len(outliers))])

Xo = np.concatenate((X[:,1],x_outliers), axis=0)
yo = np.concatenate((y,y_outliers), axis=0)

plt.scatter(X[:,1],y)
plt.scatter(x_outliers,y_outliers, c='red', marker='x')
plt.title('Data generated with outliers')
plt.show();

# %%
a, b, c = regression(Xo.reshape(-1,1), yo)
a1, b1, c1 = regression(X[:,1].reshape(-1,1), y)
print('Regression slope : %.3f' % a1, 'Regression intercept : %.3f' % b1, 'Regression score : %.3f' % c1)
print('Outliers Regression slope : %.3f' % a, 'Outliers Regression intercept : %.3f' % b, 'Outliers Regression score : %.3f' % c)
plt.plot(Xo,a*Xo+b, c='red', label='Regression Line with outliers')
plt.plot(Xo,a1*Xo+b1, c='green', label='Regression Line without outliers')
plt.legend(loc='upper left')
plt.scatter(X[:,1],y)
plt.scatter(x_outliers,y_outliers, c='red', marker='x')
plt.title('Linear Regression fit on generated data with added outliers')
plt.show();
# Out:
# Regression slope : 2.016 Regression intercept : -1.108 Regression score : 0.991
# Outliers Regression slope : 1.407 Outliers Regression intercept : -3.000 Outliers Regression score : 0.520

# %%
## Checking distance of the points from the fitted line
### We use the line fitted with outliers supposing that we havent removed them yet

distances = []
for i in range(len(yo)):
    distance = np.absolute((a*Xo[i]+b-yo[i])/(np.sqrt(a**2+1)))
    distances.append(distance)

norms = [np.sqrt(x) for x in distances]
points = np.arange(len(yo))
plt.scatter(points[-6:], norms[-6:], c='red', label=' Outliers ')
plt.scatter(points[:-6], norms[:-6], label = 'Regular points ')
plt.legend()
plt.title('Scatter plot of distance of the points from the regression line')
plt.show();

# %% [markdown]
# ## Metrics for defining an outlier :
#
# We will say that a point is an outlier if it is located further than two standard deviations above or below the best-fit line  :
#
#
# <center> $\left | y-\widehat{y} \right |> 2 \sqrt{\frac{SSE}{n-2}}$ </center>
#
# With $n$ number of data points and SSE is sum of squared errors.
#
#
#
#
# Resources : (https://stats.libretexts.org/Bookshelves/Introductory_Statistics/Book%3A_Introductory_Statistics_(OpenStax)/12%3A_Linear_Regression_and_Correlation/12.07%3A_Outliers)

# %% [markdown]
# For the example before we compute $ s =  2 \sqrt{\frac{SSE}{n-2}}$ first.

# %% [markdown]
# Let's visualise the regression line fit along with the line limiting the boundary of outliers.

# %%
s = (-1,2)
X, y = generate_data(s, 2, 100)

## Adding one outlier
outliers = [(5,-5),(7,4)]
x_outliers = np.array([outliers[i][0] for i in range(len(outliers))])
y_outliers = np.array([outliers[i][1] for i in range(len(outliers))])
Xo = np.concatenate((X[:,1],x_outliers), axis=0)
yo = np.concatenate((y,y_outliers), axis=0)
plt.scatter(X[:,1],y)
plt.scatter(x_outliers,y_outliers, c='red', marker='x')
plt.title('Data generated with outliers')
plt.show();

# %%
a, b, c = regression(Xo.reshape(-1,1), yo)
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)
plt.plot(Xo,a*Xo+b, c='red')
plt.scatter(Xo[:-2],yo[:-2])
plt.scatter(Xo[-2:],yo[-2:], marker='x')
plt.title('Linear Regression fit on generated data with added outlier')
plt.show();
# Out:
# Regression slope : 1.994 Regression intercept : -1.415 Regression score : 0.983

# %%
## Lets compute s

squared_errors = [(a*Xo[i]+b-yo[i])**2 for i in range(len(yo))]

sse = sum(squared_errors)

s = np.sqrt(sse/(len(yo)-2))

print('s : %.2f' % s)
# Out:
# s : 2.26

# %%
## Lets plot the decision boundary for outliers

x = np.linspace(-20,20,50)
plt.plot(x,a*x+b, c='red', label='Regression line')
plt.plot(x,a*x+b+2*s, c='green', label = 'Boundary lines' , marker="_")
plt.plot(x,a*x+b-2*s, c='green', marker="_" )
plt.scatter(Xo[:-2],yo[:-2])
plt.scatter(Xo[-2:],yo[-2:], marker='x')
plt.title('Linear Regression fit and outlier boundaries')
plt.legend()
plt.show();

# %% [markdown]
# We can also detect outliers by computing the residual errors.

# %%
indices = []

for i in range(len(yo)) :
    if np.absolute(a*Xo[i]+b-yo[i]) > 2*s :
        indices.append(i)
        
print(indices)
# Out:
# [19, 100, 101]

# %% [markdown]
# ## Impact of number of outliers on the Regression

# %%
### Generating Data Points
s=(-1,2)
data = Data2D(s, 3)
X,y = data.generate_points(200)
title = '200 Points Generated '
plt.title(title)
plt.scatter(X[:,1],y);

# %%
## Fitting the regression line and printig the parameters
a, b, c = regression(X[:,1].reshape(-1,1), y)
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)
print('Original line slope : %.3f' % s[1], 'Original line intercept : %.3f' % s[0])

plt.plot(X,a*X+b, c='red')
title = 'Fitting a regression Line '
plt.title(title)
plt.scatter(X[:,1],y)
plt.show();
# Out:
# Regression slope : 2.002 Regression intercept : -1.025 Regression score : 0.990
# Original line slope : 2.000 Original line intercept : -1.000

# %%
## Defining a list of 20 outlier
outliers = [(0,-20), (0,19), (5,-20), (5,26), (-5, -28), (10,-20),(15,0),(-10,6),(3,-18),(-6,6),(-1,8),(-7,10),(-1,15),(-10,1),(-4,13),(-8,3),(5,-1),(13,-2),(15,3),(3,-12)]
x_outliers = np.array([outliers[i][0] for i in range(len(outliers))])
y_outliers = np.array([outliers[i][1] for i in range(len(outliers))])
Xo = np.concatenate((X[:,1],x_outliers), axis=0)
yo = np.concatenate((y,y_outliers), axis=0)
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression score : %.3f' % c)

plt.plot(X,a*X+b, c='red')
plt.scatter(X[:,1],y, c='blue')
plt.scatter(x_outliers,y_outliers, c='orange', marker='x')
plt.scatter(X[:,1],y)
title = 'Generated data and outliers'
plt.title(title)

plt.show();
# Out:
# Regression slope : 2.002 Regression intercept : -1.025 Regression score : 0.990

# %%
## We add each time one outlier and observe the effect
slopes = []
intercepts = []
scores = []

for i in range(1,len(outliers)+1):
    
    ## Adding i outlier
    x_outliers = np.array([outliers[j][0] for j in range(i)])
    y_outliers = np.array([outliers[j][1] for j in range(i)])
    Xo = np.concatenate((X[:,1],x_outliers), axis=0)
    yo = np.concatenate((y,y_outliers), axis=0)
    
    ## Fitting the regression line
    ao, bo, co = regression(Xo.reshape(-1,1), yo)
    print(f'After adding {i} outliers : ')
    print('Original line slope : %.3f' % s[1], ', Original line intercept : %.3f' % s[0])
    print('Original Regression slope : %.3f' % a, ', Outliers Regression slope : %.3f' % ao)
    print('Original Regression intercept : %.3f' % b, ', Outliers Regression intercept : %.3f' % bo)
    print('Original Regression score : %.3f' % c, ', Outliers Regression score : %.3f' % co)
    
    

    ## Appending the parameters to the lists
    slopes.append(ao)
    intercepts.append(bo)
    scores.append(co)
    
    ## Visualisation
    plt.scatter(X[:,1],y, c='blue')
    plt.scatter(x_outliers,y_outliers, c='orange', marker='x')
    plt.plot(X,a*X+b, c='red', label = 'Original Regression line')
    plt.plot(X,ao*X+bo, c='green', label = 'Outliers Regression line')
    plt.scatter(X[:,1],y)
    title = f'Regression visualisation of outliers after adding {i} outliers'
    plt.title(title)
    plt.legend()
    plt.show();
# Out:
# After adding 1 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 2.003
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.120
# Original Regression score : 0.990 , Outliers Regression score : 0.984
# After adding 2 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 2.002
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.020
# Original Regression score : 0.990 , Outliers Regression score : 0.978
# After adding 3 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.994
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.156
# Original Regression score : 0.990 , Outliers Regression score : 0.964
# After adding 4 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.999
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.076
# Original Regression score : 0.990 , Outliers Regression score : 0.960
# After adding 5 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 2.005
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.164
# Original Regression score : 0.990 , Outliers Regression score : 0.956
# After adding 6 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.982
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.332
# Original Regression score : 0.990 , Outliers Regression score : 0.933
# After adding 7 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.956
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.445
# Original Regression score : 0.990 , Outliers Regression score : 0.921
# After adding 8 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.937
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.298
# Original Regression score : 0.990 , Outliers Regression score : 0.909
# After adding 9 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.934
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.403
# Original Regression score : 0.990 , Outliers Regression score : 0.902
# After adding 10 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.926
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.305
# Original Regression score : 0.990 , Outliers Regression score : 0.897
# After adding 11 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.924
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.251
# Original Regression score : 0.990 , Outliers Regression score : 0.895
# After adding 12 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.912
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.124
# Original Regression score : 0.990 , Outliers Regression score : 0.885
# After adding 13 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.910
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.037
# Original Regression score : 0.990 , Outliers Regression score : 0.881
# After adding 14 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.895
# Original Regression intercept : -1.025 , Outliers Regression intercept : -0.928
# Original Regression score : 0.990 , Outliers Regression score : 0.874
# After adding 15 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.889
# Original Regression intercept : -1.025 , Outliers Regression intercept : -0.823
# Original Regression score : 0.990 , Outliers Regression score : 0.867
# After adding 16 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.878
# Original Regression intercept : -1.025 , Outliers Regression intercept : -0.728
# Original Regression score : 0.990 , Outliers Regression score : 0.862
# After adding 17 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.876
# Original Regression intercept : -1.025 , Outliers Regression intercept : -0.771
# Original Regression score : 0.990 , Outliers Regression score : 0.860
# After adding 18 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.856
# Original Regression intercept : -1.025 , Outliers Regression intercept : -0.873
# Original Regression score : 0.990 , Outliers Regression score : 0.850
# After adding 19 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.835
# Original Regression intercept : -1.025 , Outliers Regression intercept : -0.965
# Original Regression score : 0.990 , Outliers Regression score : 0.842
# After adding 20 outliers :
# Original line slope : 2.000 , Original line intercept : -1.000
# Original Regression slope : 2.002 , Outliers Regression slope : 1.833
# Original Regression intercept : -1.025 , Outliers Regression intercept : -1.038
# Original Regression score : 0.990 , Outliers Regression score : 0.838

# %%
# Visualisation of regression parameters



fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
plt.figure(figsize=(20, 20), dpi=80)
fig.tight_layout()


x = np.arange(20)+1

ax1.plot(x, slopes)
ax2.plot(x, intercepts)
ax3.plot(x, scores)

ax1.set_title('Regression slope')
ax2.set_title('Regression intercept')
ax3.set_title('Regression score')

ax1.set_xlabel('Number of outliers added')
ax2.set_xlabel('Number of outliers added')
ax3.set_xlabel('Number of outliers added')



plt.show();

# %% [markdown]
# ##  Conclusion :
#
# The regression slopes may or may not change strongly, it depends on the positions of the outliers, if 2 outliers are symetric with respect to the regression line then their effect on the slope cancels out.
#
# Adding outliers always affect the regression score and make it smaller

# %%
s = (-1,2)
X, y = generate_data(s, 4, 100)
ar, br, cr = regression(X[:,1].reshape(-1,1), y)
print('Regression slope : %.3f' % ar, 'Regression intercept : %.3f' % br, 'Regression score : %.3f' % cr)
plt.plot(X[:,1],ar*X[:,1]+br, c='red')
plt.scatter(X[:,1],y)
plt.title('Linear Regression fit on generated data')
plt.show();
# Out:
# Regression slope : 1.972 Regression intercept : -1.050 Regression score : 0.990

# %%
import sklearn
from sklearn.linear_model import Lasso
from sklearn import metrics

# %%
# Create linear regression
regressor = Lasso(random_state=0,alpha=0.1)

# Fit/train LASSO
regressor.fit(X[:,1].reshape(-1,1),y)
# Predict
pred = regressor.predict(X[:,1].reshape(-1,1))

a= regressor.coef_
b = regressor.intercept_
c = np.sqrt(metrics.mean_squared_error(pred,y))
print('Regression slope : %.3f' % a, 'Regression intercept : %.3f' % b, 'Regression RMSE : %.3f' % c)
plt.plot(X[:,1],a*X[:,1]+b, c='red')
plt.scatter(X[:,1],y)
plt.title('Linear Regression fit on generated data')
plt.show();
# Out:
# Regression slope : 1.970 Regression intercept : -1.052 Regression RMSE : 1.798

# %% [markdown]
# ## Conclusion
